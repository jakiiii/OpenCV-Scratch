# %%
import numpy as np

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
from IPython import get_ipython, display
ipy = get_ipython()
if ipy is not None:
    ipy.run_line_magic('matplotlib', 'inline')

# %%
pic = Image.open('D:\Dev\OpenCV\images\mas.jpg')

# %%
print(display(pic))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x1CF03E74EF0>

# %%
print(type(pic))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
pic_arr = np.asarray(pic)

# %%
print(pic_arr.shape)
# Out:
# (480, 720, 3)

# %%
print(plt.imshow(pic_arr))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
pic_red = pic_arr.copy()

# %%
print(plt.imshow(pic_red))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
print(pic_red.shape)
# Out:
# (480, 720, 3)

# %%
print(pic_red[:, :, 0])
# Out:
# [[ 83  83  83 ... 192 192 192]
#  [ 84  84  84 ... 192 192 192]
#  [ 85  85  85 ... 192 192 192]
#  ...
#  [122 121 117 ...   4   5   6]
#  [121 120 117 ...   3   4   4]
#  [118 117 115 ...   4   4   4]]

# %%
print(plt.imshow(pic_red[:, :, 0]))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
print(plt.imshow(pic_red[:, :, 0], cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
print(plt.imshow(pic_red[:, :, 1], cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
print(plt.imshow(pic_red[:, :, 2], cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
pic_red[:, :, 1] = 0

# %%
pic_red[:, :, 2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (480, 720, 3)

# %%
pic_red[:, :, 0].shape
# Out:
# (480, 720)

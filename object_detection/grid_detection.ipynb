# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython import get_ipython
ipy = get_ipython()
if ipy is not None:
    ipy.run_line_magic('matplotlib', 'inline')

# %%
flat_chess = cv2.imread('D:\Dev\OpenCV\images\chess.jpg')

# %%
plt.imshow(flat_chess)

# %%
found, corners = cv2.findChessboardCorners(flat_chess, (5, 5))

# %%
found
# Out:
# True

# %%
# corners

# %%
cv2.drawChessboardCorners(flat_chess, (5, 5), corners, found)
# Out:
# array([[[  8,  40, 165],
#         [  6,  43, 165],
#         [  0,  43, 160],
#         ...,
#         [  0,  41, 168],
#         [  0,  42, 167],
#         [  0,  43, 164]],
#
#        [[  5,  42, 164],
#         [  4,  43, 165],
#         [  0,  45, 161],
#         ...,
#         [  0,  40, 167],
#         [  0,  42, 167],
#         [  0,  43, 164]],
#
#        [[  0,  43, 162],
#         [  0,  43, 161],
#         [  0,  44, 161],
#         ...,
#         [  0,  43, 170],
#         [  0,  40, 167],
#         [  0,  42, 165]],
#
#        ...,
#
#        [[  0,  40, 166],
#         [  3,  44, 170],
#         [  0,  40, 163],
#         ...,
#         [  0,  43, 164],
#         [  0,  42, 165],
#         [  1,  45, 168]],
#
#        [[  0,  38, 161],
#         [  0,  42, 165],
#         [  2,  44, 167],
#         ...,
#         [  0,  38, 161],
#         [  1,  45, 168],
#         [  0,  43, 164]],
#
#        [[  0,  46, 167],
#         [  0,  42, 163],
#         [  0,  42, 160],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots = cv2.imread('D:\Dev\OpenCV\images\dots.jpg')

# %%
plt.imshow(dots)

# %%
found, circle = cv2.findCirclesGrid(dots, (8, 11), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
cv2.drawChessboardCorners(dots, (8, 11), circle, found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(dots)

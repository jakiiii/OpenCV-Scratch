# %%
import numpy as np

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
from IPython import get_ipython, display
ipy = get_ipython()
if ipy is not None:
    ipy.run_line_magic('matplotlib', 'inline')

# %%
import cv2

# %%
img = cv2.imread('D:\Dev\OpenCV\images\start_bpl_2012.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (467, 700, 3)

# %%
plt.imshow(img)

# %%
# For this weird reason of this pic,
# MATPLOTLIB --> RED, GREEN, BLUE
# OPENCV --> BLUE, GREEN, RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('D:\Dev\OpenCV\images\start_bpl_2012.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (467, 700)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (467, 700, 3)

# %%
new_img = cv2.resize(fix_img, (500, 300))

# %%
new_img.shape
# Out:
# (300, 500, 3)

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8  # 80% of original width
h_ratio = 0.4  # 20% of original height

# %%
new_img = cv2.resize(fix_img, (0, 0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (187, 560, 3)

# %%
new_img = cv2.flip(fix_img, -1)

# %%
plt.imshow(new_img)

# %%
type(fix_img)
plt.imshow(fix_img)

# %%
cv2.imwrite('D:\Dev\OpenCV\make_image\match_2012.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2, 2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
